# %%
import requests
import pandas as pd
df=0

# Define the API endpoint
url = "https://api.coingecko.com/api/v3/coins/markets"

# Define the parameters for the API request
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1,
    "sparkline": False
}

# Make the API request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    data = response.json()
    
    # Create a DataFrame from the data
    df = pd.DataFrame(data)
    
    # Display the DataFrame
   
    
 
    
else:
    print(f"Failed to fetch data: {response.status_code}")

# type(df)

df["name"]

# df

# df.to_csv("crypto_data.csv")

df
# Out:
#                     id symbol                name  \
# 0              bitcoin    btc             Bitcoin
# 1             ethereum    eth            Ethereum
# 2               ripple    xrp                 XRP
# 3               tether   usdt              Tether
# 4          binancecoin    bnb                 BNB
# ..                 ...    ...                 ...
# 95               usdt0  usdt0               USDT0
# 96          blockstack    stx              Stacks
# 97                nexo   nexo                NEXO
# 98  renzo-restaked-eth  ezeth  Renzo Restaked ETH
# 99               floki  floki               FLOKI
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...  118946.000000
# 1   https://coin-images.coingecko.com/coins/images...    3886.530000
# 2   https://coin-images.coingecko.com/coins/images...       3.260000
# 3   https://coin-images.coingecko.com/coins/images...       1.000000
# ...

# %%
df = df[["name","current_price"]]

# if we want to chnage the Data type
df["current_price"]=df["current_price"].astype("int")


df
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_16184\950293914.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["current_price"]=df["current_price"].astype("int")
#                   name  current_price
# 0              Bitcoin         118946
# 1             Ethereum           3886
# 2                  XRP              3
# 3               Tether              1
# 4                  BNB            856
# ..                 ...            ...
# 95               USDT0              0
# 96              Stacks              0
# 97                NEXO              1
# 98  Renzo Restaked ETH           4084
# 99               FLOKI              0
#
# [100 rows x 2 columns]

# %%
# df.set_index("name",inplace=True)
df
# Out:
#                   name  current_price
# 0              Bitcoin         118946
# 1             Ethereum           3886
# 2                  XRP              3
# 3               Tether              1
# 4                  BNB            856
# ..                 ...            ...
# 95               USDT0              0
# 96              Stacks              0
# 97                NEXO              1
# 98  Renzo Restaked ETH           4084
# 99               FLOKI              0
#
# [100 rows x 2 columns]

# %% [markdown]
# # Series Mthods

# %%
df.head(10)
# Out:
#                 name  current_price
# 0            Bitcoin         118946
# 1           Ethereum           3886
# 2                XRP              3
# 3             Tether              1
# 4                BNB            856
# 5             Solana            192
# 6               USDC              0
# 7           Dogecoin              0
# 8  Lido Staked Ether           3883
# 9               TRON              0

# %%
df.tail(20)
# Before Last
# Out:
#                                            name  current_price
# 80                           Lombard Staked BTC         118776
# 81  Jupiter Perpetuals Liquidity Provider Token              5
# 82                                        sUSDS              1
# 83                                    Injective             16
# 84                                     Optimism              0
# 85                                     Celestia              2
# 86                                  XDC Network              0
# 87                                       KuCoin             11
# 88                         StakeWise Staked ETH           4052
# 89                                        USDtb              0
# 90                          Mantle Staked Ether           4159
# 91                            Liquid Staked ETH           4202
# 92                                    Curve DAO              1
# 93                                     Fartcoin              1
# ...

# %%
df.sample(5)
# why we take sample of Data 1)  1)biased 3)Last might be biger and the firstValue might smaller 
#
# Out:
#                     name  current_price
# 8      Lido Staked Ether           3883
# 96                Stacks              0
# 40    Ethena Staked USDe              1
# 58      Binance-Peg WETH           3864
# 88  StakeWise Staked ETH           4052

# %%
# Value counts
price = df["current_price"]
price.value_counts(ascending=True)
# Out:
# current_price
# 118946     1
# 3886       1
# 192        1
# 856        1
# 3883       1
# 4175       1
# 118673     1
# 4695       1
# 580        1
# 26         1
# 19         1
# 119002     1
# 8          1
# 114        1
# 3888       1
# 4166       1
# 18         1
# 23         1
# 234        1
# 49         1
# 3864       1
# 326        1
# 305        1
# 430        1
# 4052       1
# 16         1
# 118776     1
# 4077       1
# 4428       1
# 129        1
# 205        1
# 10         1
# 4159       1
# 4202       1
# 4084       1
# 44         2
# 11         2
# 5          3
# 3          3
# 2          3
# 4          7
# 1         11
# 0         34
# Name: count, dtype: int64

# %%
price.sort_values(ascending=False)
# Out:
# 33    119002
# 0     118946
# 80    118776
# 12    118673
# 11      4695
#        ...
# 86         0
# 95         0
# 94         0
# 96         0
# 99         0
# Name: current_price, Length: 100, dtype: int64

# %%
price.sort_index()
# Out:
# 0     118946
# 1       3886
# 2          3
# 3          1
# 4        856
#        ...
# 95         0
# 96         0
# 97         1
# 98      4084
# 99         0
# Name: current_price, Length: 100, dtype: int64

# %% [markdown]
# ### Math Functions

# %%
print(df.count())
print(df.size)
# df.size returns total number of elements (rows × columns), including NaNs.
# size attribute returns count NAN value however count  returns only unique value
# Out:
# name             100
# current_price    100
# dtype: int64
# 200

# %%
print(df["current_price"].sum())
print(df["current_price"].product())

print(df["current_price"].min())
print(df["current_price"].max())

df.describe()

# count refers to the number of non-null values in the current_price column.
# Out:
# 532675
# 0
# 0
# 119002
#        current_price
# count     100.000000
# mean     5326.750000
# std     23330.342024
# min         0.000000
# 25%         0.000000
# 50%         3.000000
# 75%       144.750000
# max    119002.000000

# %%
print(df["current_price"] )
print(df["current_price"] + 1000)
# we can add scalar product on it
# Out:
# 0     118946
# 1       3886
# 2          3
# 3          1
# 4        856
#        ...
# 95         0
# 96         0
# 97         1
# 98      4084
# 99         0
# Name: current_price, Length: 100, dtype: int64
# 0     119946
# 1       4886
# 2       1003
# 3       1001
# 4       1856
#        ...
# 95      1000
# 96      1000
# 97      1001
# 98      5084
# 99      1000
# Name: current_price, Length: 100, dtype: int64

# %%
price = df.set_index("name")["current_price"]

price.sample(5).plot()

df.set_index("name",inplace=True)
# df["current_price"]

# %%
# arr = pd.Series([10,20,30,40],name="weightOfChildren")

series_Data = df.squeeze()

# df

series_Data.sample(10).sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='name'>
