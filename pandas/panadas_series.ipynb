# %%
# Series 
# One dimensional array like object that can hold any data type. it is similer to column in table


# Data frame

# %%
import pandas as pd

# df = pd.read_csv('D:\python_lib\pandas\world_population.csv',header=None)
df = pd.read_csv('world_population.csv')

df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df['Rank'] = df['Rank'].astype('str')

# %%
df['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: object

# %%
df['Rank'].head(10)
# Out:
# 0     36
# 1    138
# 2     34
# 3    213
# 4    203
# 5     42
# 6    224
# 7    201
# 8     33
# 9    140
# Name: Rank, dtype: object

# %%
top_10 = df[['Rank','Country']].head(10)
top_10.sample(5)

# it gives Random row 
top_10['Country']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
# 5                 Angola
# 6               Anguilla
# 7    Antigua and Barbuda
# 8              Argentina
# 9                Armenia
# Name: Country, dtype: object

# %%
# top_10['Country'].name = 'Nation'

df['Country'].name = "Nation" 
df['Country']

df.rename(columns={'Country': 'Nation'}, inplace=True)

# %%
df['Nation']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
#              ...
# 229    Wallis and Futuna
# 230       Western Sahara
# 231                Yemen
# 232               Zambia
# 233             Zimbabwe
# Name: Nation, Length: 234, dtype: object

# %%
df.value_counts()
# Out:
# Rank  CCA3  Nation                Capital      Continent      2022 Population  2020 Population  2015 Population  2010 Population  2000 Population  1990 Population  1980 Population  1970 Population  Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 1     CHN   China                 Beijing      Asia           1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09     1.264099e+09     1.153704e+09     982372466.0      822534450.0      9706961.0   146.8933           1.0000       17.88                          1
# 10    MEX   Mexico                Mexico City  North America  1.275041e+08     1.259983e+08     1.201499e+08     1.125324e+08     9.787344e+07     8.172043e+07     67705186.0       50289306.0       1964375.0   64.9082            1.0063       1.60                           1
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Nation, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []
