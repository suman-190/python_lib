# %%
import requests
import pandas as pd
df=0

# Define the API endpoint
url = "https://api.coingecko.com/api/v3/coins/markets"

# Define the parameters for the API request
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 100,
    "page": 1,
    "sparkline": False
}

# Make the API request
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    data = response.json()
    
    # Create a DataFrame from the data
    df = pd.DataFrame(data)
    
    # Display the DataFrame
 
    
 
    
else:
    print(f"Failed to fetch data: {response.status_code}")

# type(df)
# 

df
# Out:
#                     id symbol                name  \
# 0              bitcoin    btc             Bitcoin
# 1             ethereum    eth            Ethereum
# 2               ripple    xrp                 XRP
# 3               tether   usdt              Tether
# 4          binancecoin    bnb                 BNB
# ..                 ...    ...                 ...
# 95               usdt0  usdt0               USDT0
# 96          blockstack    stx              Stacks
# 97                nexo   nexo                NEXO
# 98  renzo-restaked-eth  ezeth  Renzo Restaked ETH
# 99               floki  floki               FLOKI
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...  118617.000000
# 1   https://coin-images.coingecko.com/coins/images...    3849.330000
# 2   https://coin-images.coingecko.com/coins/images...       3.190000
# 3   https://coin-images.coingecko.com/coins/images...       0.999960
# ...

# %%
df = df[["name","current_price"]]

df["current_price"] = df["current_price"].astype("int")

df
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_14596\26007329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["current_price"] = df["current_price"].astype("int")
#                   name  current_price
# 0              Bitcoin         118617
# 1             Ethereum           3849
# 2                  XRP              3
# 3               Tether              0
# 4                  BNB            845
# ..                 ...            ...
# 95               USDT0              0
# 96              Stacks              0
# 97                NEXO              1
# 98  Renzo Restaked ETH           4048
# 99               FLOKI              0
#
# [100 rows x 2 columns]

# %%
df.head(10)
# Out:
#                 name  current_price
# 0            Bitcoin         118617
# 1           Ethereum           3849
# 2                XRP              3
# 3             Tether              0
# 4                BNB            845
# 5             Solana            190
# 6               USDC              0
# 7           Dogecoin              0
# 8  Lido Staked Ether           3845
# 9               TRON              0

# %%
df.tail(10)
# Before last
# Out:
#                   name  current_price
# 90            Optimism              0
# 91   Liquid Staked ETH           4156
# 92           Curve DAO              0
# 93   First Digital USD              0
# 94            Fartcoin              1
# 95               USDT0              0
# 96              Stacks              0
# 97                NEXO              1
# 98  Renzo Restaked ETH           4048
# 99               FLOKI              0

# %% [markdown]
# ****

# %%
df.sample(10)
# Out:
#                  name  current_price
# 69          Fasttoken              4
# 40             Ethena              0
# 2                 XRP              3
# 25          LEO Token              8
# 38               Aave            299
# 6                USDC              0
# 68                Sky              0
# 20          Avalanche             27
# 67     Official Trump             10
# 91  Liquid Staked ETH           4156

# %%
price = df["current_price"]

price.value_counts()
# Out:
# current_price
# 0         36
# 1          9
# 4          7
# 2          4
# 5          3
# 3845       2
# 3          2
# 10         2
# 18         2
# 44         2
# 4632       1
# 118483     1
# 845        1
# 3849       1
# 118617     1
# 190        1
# 584        1
# 112        1
# 4125       1
# 27         1
# 8          1
# 118588     1
# 326        1
# 299        1
# 4137       1
# 420        1
# 22         1
# 232        1
# 49         1
# 3840       1
# 203        1
# 126        1
# 4372       1
# 4037       1
# 118037     1
# 15         1
# 11         1
# 4047       1
# 4122       1
# 4156       1
# 4048       1
# Name: count, dtype: int64

# %%
price
# Out:
# 0     118617
# 1       3849
# 2          3
# 3          0
# 4        845
#        ...
# 95         0
# 96         0
# 97         1
# 98      4048
# 99         0
# Name: current_price, Length: 100, dtype: int64

# %%
price.sort_values(ascending=False)
# Out:
# 0     118617
# 33    118588
# 12    118483
# 79    118037
# 11      4632
#        ...
# 92         0
# 95         0
# 93         0
# 96         0
# 99         0
# Name: current_price, Length: 100, dtype: int64

# %%
print(df.count())
print(df.size)
# size attribute returns count NAN value however count returns inly unique value
# Out:
# name             100
# current_price    100
# dtype: int64
# 200

# %% [markdown]
# ### Math

# %%
print(df["current_price"].sum())
print(df["current_price"].product())
print(df["current_price"].max())
print(df["current_price"].min())



# print(df["current_price"] + 1000)
# Out:
# 530459
# 0
# 118617
# 0

# %%
price = df.set_index("name")["current_price"]

price.sample(10).plot(kind="bar")

df.set_index("name",inplace=True)

# %%
price.head(10).plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 30,40,20,30,40
